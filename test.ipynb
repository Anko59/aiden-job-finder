# %%
from aiden_app.tools.utils.wtj_scraper import WelcomeToTheJungleScraper, JobOffer
import pydantic
from mistralai.client import MistralClient, EmbeddingResponse
from sklearn.metrics.pairwise import euclidean_distances

# %%
scraper = WelcomeToTheJungleScraper()
# Out:
# 2024-05-10 17:10:13.009 | INFO     | aiden_app.tools.utils.wtj_scraper:__init__:146 - succesfully initialized WTJ scraper

# %%
ml_eng_results = scraper._fetch_results(search_query="Données/Business Intelligence", location="Paris")

# %%
len(ml_eng_results)
# Out:
# 1000

# %%
marketing_results = scraper._fetch_results(search_query="marketing", location="Paris")

# %%
po_results = scraper._fetch_results(search_query="product owner", location="Bordeaux")

# %%
boucher_results = scraper._fetch_results(search_query="Boucher", location="Reims")

# %%
client = MistralClient(api_key="PVFKaHc9pK0Gyj2AaQfUVAsQjFYlLJFp")

# %%
def embed_offer_list(offers: list[JobOffer], chunk_size: int = 5) -> list[EmbeddingResponse]:
    embeddings: list[EmbeddingResponse] = []
    chunks: list[list[JobOffer]] = [offers[i : i + chunk_size] for i in range(0, len(offers), chunk_size)]
    for chunk in chunks:
        embeddings_batch_response = client.embeddings(
            model="mistral-embed",
            input=[offer.metadata_repr() for offer in chunk],
        )
        embeddings += embeddings_batch_response.data
    return embeddings

# %%
boucher_results
# Out:
# [JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=None, contract_type='full_time', education_level=None, experience_level_minimum=None, has_contract_duration=False, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=True, language='fr', name='Boucher F/H', new_profession=Profession(category_name='Entretien et réparation', sub_category_name="Services généraux d'entretien et de réparation", sub_category_reference='general-maintenance-and-repair-wYjIw'), offices=[Office(country='France', local_city='Crest', local_state='Auvergne-Rhône-Alpes')], organization=Organization(description='L’expérience Auchan est une expérience que nous créons… ensemble !\n\nC’est une expérience collective où l’esprit d’équipe prime, une expérience épanouissante où chacun peut créer son propre parcours, une expérience engagée où l’on s’investit dans la quête d’un objectif commun : AMÉLIORER LE QUOTIDIEN ! Avec près de 700 magasins en France et trois sites dédiés aux fonctions support dans l’agglomération lilloise (Auchan Retail France, Direction Produit Worldwide et Auchan Retail International), une grande diversité de métiers s’offre à vous. Votre quotidien en sera transformé, et jamais lassant. Vous apprendrez à nos côtés et évoluerez dans votre carrière. Vous serez accueilli au sein d’un Groupe singulier, à la fois familial et mondial, humain et dynamique, historique et tourné vers l’avenir. Nous sommes impatients de vous rencontrer !', name='Auchan Retail', nb_employees=59000), profile='📢Nous vous offrons les avantages suivants :\r\n\r\n\r\n• Une remise sur achat chez Auchan\r\n• Des primes de participation et d’intéressement selon la performance annuelle de l’entreprise\r\n• Une prime annuelle équivalente à un 13e mois\r\n\r\n\r\nChez Auchan, nous sommes convaincus que la diversité fait la richesse d’une entreprise. Nous étudions à compétences égales chaque candidature et toutes nos offres peuvent faire l’objet d’aménagements spécifiques en cas de handicap - #tous égaux, tous différents !\r\n\r\n\r\n🌳Vous voulez en savoir plus sur nos engagements ?\r\nNous nous mobilisons au quotidien autour de 4 piliers de responsabilité sociétale et environnementale majeurs : Offre responsable, Environnement, Solidarité, Humain.\r\nRendez-vous sur : https://www.auchan-agit.fr.\r\n\r\n\r\n\r\n\r\n\xa0\r\n', published_at='2024-05-10T10:28:30Z', remote='no', salary_currency='EUR', salary_maximum=25480, salary_minimum=25000, salary_period='yearly', salary_yearly_minimum=25000, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=None, contract_type='full_time', education_level=None, experience_level_minimum=None, has_contract_duration=False, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=True, language='fr', name='Boucher F/H', new_profession=Profession(category_name='Entretien et réparation', sub_category_name="Services généraux d'entretien et de réparation", sub_category_reference='general-maintenance-and-repair-wYjIw'), offices=[Office(country='France', local_city='Marlenheim', local_state='Grand Est')], organization=Organization(description='L’expérience Auchan est une expérience que nous créons… ensemble !\n\nC’est une expérience collective où l’esprit d’équipe prime, une expérience épanouissante où chacun peut créer son propre parcours, une expérience engagée où l’on s’investit dans la quête d’un objectif commun : AMÉLIORER LE QUOTIDIEN ! Avec près de 700 magasins en France et trois sites dédiés aux fonctions support dans l’agglomération lilloise (Auchan Retail France, Direction Produit Worldwide et Auchan Retail International), une grande diversité de métiers s’offre à vous. Votre quotidien en sera transformé, et jamais lassant. Vous apprendrez à nos côtés et évoluerez dans votre carrière. Vous serez accueilli au sein d’un Groupe singulier, à la fois familial et mondial, humain et dynamique, historique et tourné vers l’avenir. Nous sommes impatients de vous rencontrer !', name='Auchan Retail', nb_employees=59000), profile='📢Nous vous offrons les avantages suivants :\r\n\r\n\r\n• Une remise sur achat chez Auchan\r\n• Des primes de participation et d’intéressement selon la performance annuelle de l’entreprise\r\n• Une prime annuelle équivalente à un 13e mois\r\n\r\n\r\nChez Auchan, nous sommes convaincus que la diversité fait la richesse d’une entreprise. Nous étudions à compétences égales chaque candidature et toutes nos offres peuvent faire l’objet d’aménagements spécifiques en cas de handicap - #tous égaux, tous différents !\r\n\r\n\r\n🌳Vous voulez en savoir plus sur nos engagements ?\r\nNous nous mobilisons au quotidien autour de 4 piliers de responsabilité sociétale et environnementale majeurs : Offre responsable, Environnement, Solidarité, Humain.\r\nRendez-vous sur : https://www.auchan-agit.fr.\r\n\r\n\r\n\r\n\r\n\xa0\r\n', published_at='2024-05-10T10:20:08Z', remote='no', salary_currency='EUR', salary_maximum=27010, salary_minimum=25480, salary_period='yearly', salary_yearly_minimum=25480, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=None, contract_type='full_time', education_level=None, experience_level_minimum=None, has_contract_duration=False, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=True, language='fr', name='Boucher stand F/H', new_profession=Profession(category_name='Artisanat et travail manuel', sub_category_name='Production et préparation des aliments', sub_category_reference='food-production-and-preparation-zODEx'), offices=[Office(country='France', local_city='Mâcon', local_state='Bourgogne-Franche-Comté')], organization=Organization(description='L’expérience Auchan est une expérience que nous créons… ensemble !\n\nC’est une expérience collective où l’esprit d’équipe prime, une expérience épanouissante où chacun peut créer son propre parcours, une expérience engagée où l’on s’investit dans la quête d’un objectif commun : AMÉLIORER LE QUOTIDIEN ! Avec près de 700 magasins en France et trois sites dédiés aux fonctions support dans l’agglomération lilloise (Auchan Retail France, Direction Produit Worldwide et Auchan Retail International), une grande diversité de métiers s’offre à vous. Votre quotidien en sera transformé, et jamais lassant. Vous apprendrez à nos côtés et évoluerez dans votre carrière. Vous serez accueilli au sein d’un Groupe singulier, à la fois familial et mondial, humain et dynamique, historique et tourné vers l’avenir. Nous sommes impatients de vous rencontrer !', name='Auchan Retail', nb_employees=59000), profile='📢Nous vous offrons les avantages suivants :\r\n\r\n\r\n• Une remise sur achat chez Auchan\r\n• Des primes de participation et d’intéressement selon la performance annuelle de l’entreprise\r\n• Une prime annuelle équivalente à un 13e mois\r\n\r\n\r\nChez Auchan, nous sommes convaincus que la diversité fait la richesse d’une entreprise. Nous étudions à compétences égales chaque candidature et toutes nos offres peuvent faire l’objet d’aménagements spécifiques en cas de handicap - #tous égaux, tous différents !\r\n\r\n\r\n🌳Vous voulez en savoir plus sur nos engagements ?\r\nNous nous mobilisons au quotidien autour de 4 piliers de responsabilité sociétale et environnementale majeurs : Offre responsable, Environnement, Solidarité, Humain.\r\nRendez-vous sur : https://www.auchan-agit.fr.\r\n\r\n\r\n', published_at='2024-05-10T07:34:11Z', remote='no', salary_currency='EUR', salary_maximum=27010, salary_minimum=25480, salary_period='yearly', salary_yearly_minimum=25480, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=None, contract_type='full_time', education_level=None, experience_level_minimum=None, has_contract_duration=False, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=True, language='fr', name='Boucher F/H', new_profession=Profession(category_name='Entretien et réparation', sub_category_name="Services généraux d'entretien et de réparation", sub_category_reference='general-maintenance-and-repair-wYjIw'), offices=[Office(country='France', local_city='Haguenau', local_state='Grand Est')], organization=Organization(description='L’expérience Auchan est une expérience que nous créons… ensemble !\n\nC’est une expérience collective où l’esprit d’équipe prime, une expérience épanouissante où chacun peut créer son propre parcours, une expérience engagée où l’on s’investit dans la quête d’un objectif commun : AMÉLIORER LE QUOTIDIEN ! Avec près de 700 magasins en France et trois sites dédiés aux fonctions support dans l’agglomération lilloise (Auchan Retail France, Direction Produit Worldwide et Auchan Retail International), une grande diversité de métiers s’offre à vous. Votre quotidien en sera transformé, et jamais lassant. Vous apprendrez à nos côtés et évoluerez dans votre carrière. Vous serez accueilli au sein d’un Groupe singulier, à la fois familial et mondial, humain et dynamique, historique et tourné vers l’avenir. Nous sommes impatients de vous rencontrer !', name='Auchan Retail', nb_employees=59000), profile='📢Nous vous offrons les avantages suivants :\r\n\r\n\r\n• Une remise sur achat chez Auchan\r\n• Des primes de participation et d’intéressement selon la performance annuelle de l’entreprise\r\n• Une prime annuelle équivalente à un 13e mois\r\n\r\n\r\nChez Auchan, nous sommes convaincus que la diversité fait la richesse d’une entreprise. Nous étudions à compétences égales chaque candidature et toutes nos offres peuvent faire l’objet d’aménagements spécifiques en cas de handicap - #tous égaux, tous différents !\r\n\r\n\r\n🌳Vous voulez en savoir plus sur nos engagements ?\r\nNous nous mobilisons au quotidien autour de 4 piliers de responsabilité sociétale et environnementale majeurs : Offre responsable, Environnement, Solidarité, Humain.\r\nRendez-vous sur : https://www.auchan-agit.fr.\r\n\r\n\r\n\r\n\r\n\xa0\r\n', published_at='2024-05-07T15:25:01Z', remote='no', salary_currency='EUR', salary_maximum=27010, salary_minimum=25480, salary_period='yearly', salary_yearly_minimum=25480, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=24, contract_type='apprenticeship', education_level=None, experience_level_minimum=None, has_contract_duration=True, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=True, language='fr', name='Boucher en alternance F/H', new_profession=Profession(category_name='Accueil', sub_category_name='Gestion hôtelière', sub_category_reference='hospitality-management-iODMx'), offices=[Office(country='France', local_city='Paris', local_state='Île-de-France')], organization=Organization(description='L’expérience Auchan est une expérience que nous créons… ensemble !\n\nC’est une expérience collective où l’esprit d’équipe prime, une expérience épanouissante où chacun peut créer son propre parcours, une expérience engagée où l’on s’investit dans la quête d’un objectif commun : AMÉLIORER LE QUOTIDIEN ! Avec près de 700 magasins en France et trois sites dédiés aux fonctions support dans l’agglomération lilloise (Auchan Retail France, Direction Produit Worldwide et Auchan Retail International), une grande diversité de métiers s’offre à vous. Votre quotidien en sera transformé, et jamais lassant. Vous apprendrez à nos côtés et évoluerez dans votre carrière. Vous serez accueilli au sein d’un Groupe singulier, à la fois familial et mondial, humain et dynamique, historique et tourné vers l’avenir. Nous sommes impatients de vous rencontrer !', name='Auchan Retail', nb_employees=59000), profile='📢Nous vous offrons les avantages suivants :\r\n\r\n\r\n• Une remise sur achat chez Auchan\r\n• Des primes de participation et d’intéressement selon la performance annuelle de l’entreprise\r\n• Une prime annuelle équivalente à un 13e mois\r\n\r\n\r\nChez Auchan, nous sommes convaincus que la diversité fait la richesse d’une entreprise. Nous étudions à compétences égales chaque candidature et toutes nos offres peuvent faire l’objet d’aménagements spécifiques en cas de handicap - #tous égaux, tous différents !\r\n\r\n\r\n🌳Vous voulez en savoir plus sur nos engagements ?\r\nNous nous mobilisons au quotidien autour de 4 piliers de responsabilité sociétale et environnementale majeurs : Offre responsable, Environnement, Solidarité, Humain.\r\nRendez-vous sur : https://www.auchan-agit.fr.\r\n', published_at='2024-05-06T14:29:55Z', remote='no', salary_currency='EUR', salary_maximum=23840, salary_minimum=19040, salary_period='yearly', salary_yearly_minimum=19040, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=None, contract_type='full_time', education_level=None, experience_level_minimum=None, has_contract_duration=False, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=True, language='fr', name='Chef Boucher F/H', new_profession=Profession(category_name='Accueil', sub_category_name='Alimentation et boissons', sub_category_reference='food-and-beverage-jNWVi'), offices=[Office(country='France', local_city='Paris', local_state='Île-de-France')], organization=Organization(description='L’expérience Auchan est une expérience que nous créons… ensemble !\n\nC’est une expérience collective où l’esprit d’équipe prime, une expérience épanouissante où chacun peut créer son propre parcours, une expérience engagée où l’on s’investit dans la quête d’un objectif commun : AMÉLIORER LE QUOTIDIEN ! Avec près de 700 magasins en France et trois sites dédiés aux fonctions support dans l’agglomération lilloise (Auchan Retail France, Direction Produit Worldwide et Auchan Retail International), une grande diversité de métiers s’offre à vous. Votre quotidien en sera transformé, et jamais lassant. Vous apprendrez à nos côtés et évoluerez dans votre carrière. Vous serez accueilli au sein d’un Groupe singulier, à la fois familial et mondial, humain et dynamique, historique et tourné vers l’avenir. Nous sommes impatients de vous rencontrer !', name='Auchan Retail', nb_employees=59000), profile='📢Nous vous offrons les avantages suivants :\r\n\r\n\r\n• Une remise sur achat chez Auchan\r\n• Des primes de participation et d’intéressement selon la performance annuelle de l’entreprise\r\n• Une prime annuelle équivalente à un 13e mois\r\n\r\n\r\nChez Auchan, nous sommes convaincus que la diversité fait la richesse d’une entreprise. Nous étudions à compétences égales chaque candidature et toutes nos offres peuvent faire l’objet d’aménagements spécifiques en cas de handicap - #tous égaux, tous différents !\r\n\r\n\r\n🌳Vous voulez en savoir plus sur nos engagements ?\r\nNous nous mobilisons au quotidien autour de 4 piliers de responsabilité sociétale et environnementale majeurs : Offre responsable, Environnement, Solidarité, Humain.\r\nRendez-vous sur : https://www.auchan-agit.fr.\r\n\r\n\r\n\r\n\r\n', published_at='2024-05-06T14:23:18Z', remote='no', salary_currency='EUR', salary_maximum=30000, salary_minimum=26000, salary_period='yearly', salary_yearly_minimum=26000, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=12, contract_type='apprenticeship', education_level=None, experience_level_minimum=None, has_contract_duration=True, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=True, language='fr', name='Boucher en alternance F/H', new_profession=Profession(category_name='Accueil', sub_category_name='Gestion hôtelière', sub_category_reference='hospitality-management-iODMx'), offices=[Office(country='France', local_city='Saint-Sébastien-sur-Loire', local_state='Pays de la Loire')], organization=Organization(description='L’expérience Auchan est une expérience que nous créons… ensemble !\n\nC’est une expérience collective où l’esprit d’équipe prime, une expérience épanouissante où chacun peut créer son propre parcours, une expérience engagée où l’on s’investit dans la quête d’un objectif commun : AMÉLIORER LE QUOTIDIEN ! Avec près de 700 magasins en France et trois sites dédiés aux fonctions support dans l’agglomération lilloise (Auchan Retail France, Direction Produit Worldwide et Auchan Retail International), une grande diversité de métiers s’offre à vous. Votre quotidien en sera transformé, et jamais lassant. Vous apprendrez à nos côtés et évoluerez dans votre carrière. Vous serez accueilli au sein d’un Groupe singulier, à la fois familial et mondial, humain et dynamique, historique et tourné vers l’avenir. Nous sommes impatients de vous rencontrer !', name='Auchan Retail', nb_employees=59000), profile='📢Nous vous offrons les avantages suivants :\r\n\r\n\r\n• Une remise sur achat chez Auchan\r\n• Des primes de participation et d’intéressement selon la performance annuelle de l’entreprise\r\n• Une prime annuelle équivalente à un 13e mois\r\n\r\n\r\nChez Auchan, nous sommes convaincus que la diversité fait la richesse d’une entreprise. Nous étudions à compétences égales chaque candidature et toutes nos offres peuvent faire l’objet d’aménagements spécifiques en cas de handicap - #tous égaux, tous différents !\r\n\r\n\r\n🌳Vous voulez en savoir plus sur nos engagements ?\r\nNous nous mobilisons au quotidien autour de 4 piliers de responsabilité sociétale et environnementale majeurs : Offre responsable, Environnement, Solidarité, Humain.\r\nRendez-vous sur : https://www.auchan-agit.fr.\r\n', published_at='2024-05-06T14:13:37Z', remote='no', salary_currency='EUR', salary_maximum=23840, salary_minimum=19040, salary_period='yearly', salary_yearly_minimum=19040, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=None, contract_type='full_time', education_level=None, experience_level_minimum=None, has_contract_duration=False, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=True, language='fr', name='Boucher F/H', new_profession=Profession(category_name='Entretien et réparation', sub_category_name="Services généraux d'entretien et de réparation", sub_category_reference='general-maintenance-and-repair-wYjIw'), offices=[Office(country='France', local_city='Saint-Sébastien-sur-Loire', local_state='Pays de la Loire')], organization=Organization(description='L’expérience Auchan est une expérience que nous créons… ensemble !\n\nC’est une expérience collective où l’esprit d’équipe prime, une expérience épanouissante où chacun peut créer son propre parcours, une expérience engagée où l’on s’investit dans la quête d’un objectif commun : AMÉLIORER LE QUOTIDIEN ! Avec près de 700 magasins en France et trois sites dédiés aux fonctions support dans l’agglomération lilloise (Auchan Retail France, Direction Produit Worldwide et Auchan Retail International), une grande diversité de métiers s’offre à vous. Votre quotidien en sera transformé, et jamais lassant. Vous apprendrez à nos côtés et évoluerez dans votre carrière. Vous serez accueilli au sein d’un Groupe singulier, à la fois familial et mondial, humain et dynamique, historique et tourné vers l’avenir. Nous sommes impatients de vous rencontrer !', name='Auchan Retail', nb_employees=59000), profile='📢Nous vous offrons les avantages suivants :\r\n\r\n\r\n• Une remise sur achat chez Auchan\r\n• Des primes de participation et d’intéressement selon la performance annuelle de l’entreprise\r\n• Une prime annuelle équivalente à un 13e mois\r\n\r\n\r\nChez Auchan, nous sommes convaincus que la diversité fait la richesse d’une entreprise. Nous étudions à compétences égales chaque candidature et toutes nos offres peuvent faire l’objet d’aménagements spécifiques en cas de handicap - #tous égaux, tous différents !\r\n\r\n\r\n🌳Vous voulez en savoir plus sur nos engagements ?\r\nNous nous mobilisons au quotidien autour de 4 piliers de responsabilité sociétale et environnementale majeurs : Offre responsable, Environnement, Solidarité, Humain.\r\nRendez-vous sur : https://www.auchan-agit.fr.\r\n\r\n\r\n', published_at='2024-05-06T13:40:29Z', remote='no', salary_currency='EUR', salary_maximum=27010, salary_minimum=25480, salary_period='yearly', salary_yearly_minimum=25480, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=None, contract_type='apprenticeship', education_level=None, experience_level_minimum=None, has_contract_duration=False, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=True, language='fr', name='Boucher en alternance F/H', new_profession=Profession(category_name='Accueil', sub_category_name='Gestion hôtelière', sub_category_reference='hospitality-management-iODMx'), offices=[Office(country='France', local_city='Cesson', local_state='Île-de-France')], organization=Organization(description='L’expérience Auchan est une expérience que nous créons… ensemble !\n\nC’est une expérience collective où l’esprit d’équipe prime, une expérience épanouissante où chacun peut créer son propre parcours, une expérience engagée où l’on s’investit dans la quête d’un objectif commun : AMÉLIORER LE QUOTIDIEN ! Avec près de 700 magasins en France et trois sites dédiés aux fonctions support dans l’agglomération lilloise (Auchan Retail France, Direction Produit Worldwide et Auchan Retail International), une grande diversité de métiers s’offre à vous. Votre quotidien en sera transformé, et jamais lassant. Vous apprendrez à nos côtés et évoluerez dans votre carrière. Vous serez accueilli au sein d’un Groupe singulier, à la fois familial et mondial, humain et dynamique, historique et tourné vers l’avenir. Nous sommes impatients de vous rencontrer !', name='Auchan Retail', nb_employees=59000), profile='📢Nous vous offrons les avantages suivants :\r\n\r\n\r\n• Une remise sur achat chez Auchan\r\n• Des primes de participation et d’intéressement selon la performance annuelle de l’entreprise\r\n• Une prime annuelle équivalente à un 13e mois\r\n\r\n\r\nChez Auchan, nous sommes convaincus que la diversité fait la richesse d’une entreprise. Nous étudions à compétences égales chaque candidature et toutes nos offres peuvent faire l’objet d’aménagements spécifiques en cas de handicap - #tous égaux, tous différents !\r\n\r\n\r\n🌳Vous voulez en savoir plus sur nos engagements ?\r\nNous nous mobilisons au quotidien autour de 4 piliers de responsabilité sociétale et environnementale majeurs : Offre responsable, Environnement, Solidarité, Humain.\r\nRendez-vous sur : https://www.auchan-agit.fr.\r\n', published_at='2024-05-06T06:37:17Z', remote='no', salary_currency='EUR', salary_maximum=23840, salary_minimum=19040, salary_period='yearly', salary_yearly_minimum=19040, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=None, contract_type='full_time', education_level=None, experience_level_minimum=None, has_contract_duration=False, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=True, language='fr', name='BOUCHER H/F', new_profession=Profession(category_name='Affaires et finance', sub_category_name='Comptabilité', sub_category_reference='accounting-5Nzg0'), offices=[Office(country='France', local_city='Vélizy-Villacoublay', local_state='Île-de-France')], organization=Organization(description='L’expérience Auchan est une expérience que nous créons… ensemble !\n\nC’est une expérience collective où l’esprit d’équipe prime, une expérience épanouissante où chacun peut créer son propre parcours, une expérience engagée où l’on s’investit dans la quête d’un objectif commun : AMÉLIORER LE QUOTIDIEN ! Avec près de 700 magasins en France et trois sites dédiés aux fonctions support dans l’agglomération lilloise (Auchan Retail France, Direction Produit Worldwide et Auchan Retail International), une grande diversité de métiers s’offre à vous. Votre quotidien en sera transformé, et jamais lassant. Vous apprendrez à nos côtés et évoluerez dans votre carrière. Vous serez accueilli au sein d’un Groupe singulier, à la fois familial et mondial, humain et dynamique, historique et tourné vers l’avenir. Nous sommes impatients de vous rencontrer !', name='Auchan Retail', nb_employees=59000), profile="Votre profil ? Vous avez un diplôme de niveau BEP/CAP ou CQP Boucherie et avez une première expérience sur un poste similaire. Vous êtes passionné.e par les produits et par la relation client. Vous êtes rigoureux.se sur les consignes et avez une bonne compréhension/logique des chiffres/ en gestion.\xa0\r\n\r\n\r\nL'essentiel ? Disposer d'une expertise en boucherie et être référent pour vos équipes. Vous êtes passionné.e et souhaitez transmettre cette passion à vos clients, en leur proposant des produits frais, et de qualité ! \r\n\r\n\r\n\ufeffParce que chez Auchan Retail ce qui compte avant tout c'est vous, venez nous faire découvrir qui vous êtes !\xa0\r\n\xa0\r\nAu sein d'une entreprise en mouvement, venez contribuer à notre projet d'entreprise. Auchan agit et propose des cursus d'intégration et de développement des compétences, pour vous permettre d'être acteur de votre parcours et vous accompagner dans vos projets.\r\n\xa0\r\nParce qu'Auchan Retail est convaincu que la diversité fait la richesse d'une entreprise, nous étudions à compétences égales toutes les candidatures.\xa0\r\n\xa0\r\n", published_at='2024-05-06T06:33:14Z', remote='no', salary_currency='EUR', salary_maximum=24000, salary_minimum=22000, salary_period='yearly', salary_yearly_minimum=22000, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=None, contract_type='full_time', education_level='cap', experience_level_minimum=1.0, has_contract_duration=False, has_education_level=True, has_experience_level_minimum=True, has_remote=True, has_salary_yearly_minimum=False, language='fr', name='Boucher H/F', new_profession=Profession(category_name='Affaires et finance', sub_category_name='Comptabilité', sub_category_reference='accounting-5Nzg0'), offices=[Office(country='France', local_city='Verrières-le-Buisson', local_state='Île-de-France')], organization=Organization(description="Le saviez-vous ? Rejoindre Carrefour, c’est rejoindre l’un des leader mondial de la distribution qui met l'accent au quotidien sur le digital, la diversité et la RSE pour satisfaire ses clients et ses collaborateurs. En tant que partenaire des Jeux Olympiques 2024, l'entreprise partage les valeurs du sport en permettant à ses équipes de se dépasser et encourage une alimentation saine au juste prix pour tous. Vous cherchez à travailler dans une entreprise dynamique où votre travail rime avec impact social et environnemental ?\r\nBienvenue chez Carrefour!", name='Carrefour', nb_employees=100000), profile='<h4> Votre profil</h4>\r\n<p> </p>\r\n<ul type="disc">\r\n<li>Titulaire d\'un CAP spécialisé en boucherie et / ou 2 à 3 ans d\'expérience du métier.</li>\r\n<li>Connaissance des produits et de la chaîne du froid.</li>\r\n<li>Bonne maîtrise culinaire et goût.</li>\r\n<li>Capacité à travailler en équipe et sens du service client. </li>\r\n</ul>', published_at='2024-05-02T11:11:15Z', remote='no', salary_currency='EUR', salary_maximum=None, salary_minimum=None, salary_period='monthly', salary_yearly_minimum=None, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=None, contract_type='full_time', education_level='cap', experience_level_minimum=1.0, has_contract_duration=False, has_education_level=True, has_experience_level_minimum=True, has_remote=True, has_salary_yearly_minimum=False, language='fr', name='Boucher H/F', new_profession=Profession(category_name='Affaires et finance', sub_category_name='Comptabilité', sub_category_reference='accounting-5Nzg0'), offices=[Office(country='France', local_city='Saint-Martin-lez-Tatinghem', local_state='Hauts-de-France')], organization=Organization(description="Le saviez-vous ? Rejoindre Carrefour, c’est rejoindre l’un des leader mondial de la distribution qui met l'accent au quotidien sur le digital, la diversité et la RSE pour satisfaire ses clients et ses collaborateurs. En tant que partenaire des Jeux Olympiques 2024, l'entreprise partage les valeurs du sport en permettant à ses équipes de se dépasser et encourage une alimentation saine au juste prix pour tous. Vous cherchez à travailler dans une entreprise dynamique où votre travail rime avec impact social et environnemental ?\r\nBienvenue chez Carrefour!", name='Carrefour', nb_employees=100000), profile='<ul type="disc">\r\n<li>Titulaire d\'un CAP spécialisé en boucherie et / ou 2 à 3 ans d\'expérience du métier.</li>\r\n<li>Connaissance des produits et de la chaîne du froid.</li>\r\n<li>Bonne maîtrise culinaire et goût.</li>\r\n<li>Capacité à travailler en équipe et sens du service client. </li>\r\n</ul>', published_at='2024-05-02T11:08:56Z', remote='no', salary_currency='EUR', salary_maximum=None, salary_minimum=None, salary_period='monthly', salary_yearly_minimum=None, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=None, contract_type='apprenticeship', education_level=None, experience_level_minimum=None, has_contract_duration=False, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=True, language='fr', name='Boucher en alternance F/H', new_profession=Profession(category_name='Accueil', sub_category_name='Gestion hôtelière', sub_category_reference='hospitality-management-iODMx'), offices=[Office(country='France', local_city='Paris', local_state='Île-de-France')], organization=Organization(description='L’expérience Auchan est une expérience que nous créons… ensemble !\n\nC’est une expérience collective où l’esprit d’équipe prime, une expérience épanouissante où chacun peut créer son propre parcours, une expérience engagée où l’on s’investit dans la quête d’un objectif commun : AMÉLIORER LE QUOTIDIEN ! Avec près de 700 magasins en France et trois sites dédiés aux fonctions support dans l’agglomération lilloise (Auchan Retail France, Direction Produit Worldwide et Auchan Retail International), une grande diversité de métiers s’offre à vous. Votre quotidien en sera transformé, et jamais lassant. Vous apprendrez à nos côtés et évoluerez dans votre carrière. Vous serez accueilli au sein d’un Groupe singulier, à la fois familial et mondial, humain et dynamique, historique et tourné vers l’avenir. Nous sommes impatients de vous rencontrer !', name='Auchan Retail', nb_employees=59000), profile='📢Nous vous offrons les avantages suivants :\r\n\r\n\r\n• Une remise sur achat chez Auchan\r\n• Des primes de participation et d’intéressement selon la performance annuelle de l’entreprise\r\n• Une prime annuelle équivalente à un 13e mois\r\n\r\n\r\nChez Auchan, nous sommes convaincus que la diversité fait la richesse d’une entreprise. Nous étudions à compétences égales chaque candidature et toutes nos offres peuvent faire l’objet d’aménagements spécifiques en cas de handicap - #tous égaux, tous différents !\r\n\r\n\r\n🌳Vous voulez en savoir plus sur nos engagements ?\r\nNous nous mobilisons au quotidien autour de 4 piliers de responsabilité sociétale et environnementale majeurs : Offre responsable, Environnement, Solidarité, Humain.\r\nRendez-vous sur : https://www.auchan-agit.fr.\r\n', published_at='2024-04-30T14:21:08Z', remote='no', salary_currency='EUR', salary_maximum=23840, salary_minimum=19040, salary_period='yearly', salary_yearly_minimum=19040, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=12, contract_type='apprenticeship', education_level=None, experience_level_minimum=None, has_contract_duration=True, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=True, language='fr', name='Boucher en alternance F/H', new_profession=Profession(category_name='Accueil', sub_category_name='Gestion hôtelière', sub_category_reference='hospitality-management-iODMx'), offices=[Office(country='France', local_city='Paris', local_state='Île-de-France')], organization=Organization(description='L’expérience Auchan est une expérience que nous créons… ensemble !\n\nC’est une expérience collective où l’esprit d’équipe prime, une expérience épanouissante où chacun peut créer son propre parcours, une expérience engagée où l’on s’investit dans la quête d’un objectif commun : AMÉLIORER LE QUOTIDIEN ! Avec près de 700 magasins en France et trois sites dédiés aux fonctions support dans l’agglomération lilloise (Auchan Retail France, Direction Produit Worldwide et Auchan Retail International), une grande diversité de métiers s’offre à vous. Votre quotidien en sera transformé, et jamais lassant. Vous apprendrez à nos côtés et évoluerez dans votre carrière. Vous serez accueilli au sein d’un Groupe singulier, à la fois familial et mondial, humain et dynamique, historique et tourné vers l’avenir. Nous sommes impatients de vous rencontrer !', name='Auchan Retail', nb_employees=59000), profile='📢Nous vous offrons les avantages suivants :\r\n\r\n\r\n• Une remise sur achat chez Auchan\r\n• Des primes de participation et d’intéressement selon la performance annuelle de l’entreprise\r\n• Une prime annuelle équivalente à un 13e mois\r\n\r\n\r\nChez Auchan, nous sommes convaincus que la diversité fait la richesse d’une entreprise. Nous étudions à compétences égales chaque candidature et toutes nos offres peuvent faire l’objet d’aménagements spécifiques en cas de handicap - #tous égaux, tous différents !\r\n\r\n\r\n🌳Vous voulez en savoir plus sur nos engagements ?\r\nNous nous mobilisons au quotidien autour de 4 piliers de responsabilité sociétale et environnementale majeurs : Offre responsable, Environnement, Solidarité, Humain.\r\nRendez-vous sur : https://www.auchan-agit.fr.\r\n', published_at='2024-04-30T14:18:35Z', remote='no', salary_currency='EUR', salary_maximum=23840, salary_minimum=19040, salary_period='yearly', salary_yearly_minimum=19040, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=12, contract_type='apprenticeship', education_level=None, experience_level_minimum=None, has_contract_duration=True, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=True, language='fr', name='Boucher en alternance F/H', new_profession=Profession(category_name='Accueil', sub_category_name='Gestion hôtelière', sub_category_reference='hospitality-management-iODMx'), offices=[Office(country='France', local_city='Mouvaux', local_state='Hauts-de-France')], organization=Organization(description='L’expérience Auchan est une expérience que nous créons… ensemble !\n\nC’est une expérience collective où l’esprit d’équipe prime, une expérience épanouissante où chacun peut créer son propre parcours, une expérience engagée où l’on s’investit dans la quête d’un objectif commun : AMÉLIORER LE QUOTIDIEN ! Avec près de 700 magasins en France et trois sites dédiés aux fonctions support dans l’agglomération lilloise (Auchan Retail France, Direction Produit Worldwide et Auchan Retail International), une grande diversité de métiers s’offre à vous. Votre quotidien en sera transformé, et jamais lassant. Vous apprendrez à nos côtés et évoluerez dans votre carrière. Vous serez accueilli au sein d’un Groupe singulier, à la fois familial et mondial, humain et dynamique, historique et tourné vers l’avenir. Nous sommes impatients de vous rencontrer !', name='Auchan Retail', nb_employees=59000), profile='📢Nous vous offrons les avantages suivants :\r\n\r\n\r\n• Une remise sur achat chez Auchan\r\n• Des primes de participation et d’intéressement selon la performance annuelle de l’entreprise\r\n• Une prime annuelle équivalente à un 13e mois\r\n\r\n\r\nChez Auchan, nous sommes convaincus que la diversité fait la richesse d’une entreprise. Nous étudions à compétences égales chaque candidature et toutes nos offres peuvent faire l’objet d’aménagements spécifiques en cas de handicap - #tous égaux, tous différents !\r\n\r\n\r\n🌳Vous voulez en savoir plus sur nos engagements ?\r\nNous nous mobilisons au quotidien autour de 4 piliers de responsabilité sociétale et environnementale majeurs : Offre responsable, Environnement, Solidarité, Humain.\r\nRendez-vous sur : https://www.auchan-agit.fr.\r\n', published_at='2024-04-30T14:17:16Z', remote='no', salary_currency='EUR', salary_maximum=23840, salary_minimum=19040, salary_period='yearly', salary_yearly_minimum=19040, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=12, contract_type='apprenticeship', education_level=None, experience_level_minimum=None, has_contract_duration=True, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=True, language='fr', name='Boucher en alternance F/H', new_profession=Profession(category_name='Accueil', sub_category_name='Gestion hôtelière', sub_category_reference='hospitality-management-iODMx'), offices=[Office(country='France', local_city='Linselles', local_state='Hauts-de-France')], organization=Organization(description='L’expérience Auchan est une expérience que nous créons… ensemble !\n\nC’est une expérience collective où l’esprit d’équipe prime, une expérience épanouissante où chacun peut créer son propre parcours, une expérience engagée où l’on s’investit dans la quête d’un objectif commun : AMÉLIORER LE QUOTIDIEN ! Avec près de 700 magasins en France et trois sites dédiés aux fonctions support dans l’agglomération lilloise (Auchan Retail France, Direction Produit Worldwide et Auchan Retail International), une grande diversité de métiers s’offre à vous. Votre quotidien en sera transformé, et jamais lassant. Vous apprendrez à nos côtés et évoluerez dans votre carrière. Vous serez accueilli au sein d’un Groupe singulier, à la fois familial et mondial, humain et dynamique, historique et tourné vers l’avenir. Nous sommes impatients de vous rencontrer !', name='Auchan Retail', nb_employees=59000), profile='📢Nous vous offrons les avantages suivants :\r\n\r\n\r\n• Une remise sur achat chez Auchan\r\n• Des primes de participation et d’intéressement selon la performance annuelle de l’entreprise\r\n• Une prime annuelle équivalente à un 13e mois\r\n\r\n\r\nChez Auchan, nous sommes convaincus que la diversité fait la richesse d’une entreprise. Nous étudions à compétences égales chaque candidature et toutes nos offres peuvent faire l’objet d’aménagements spécifiques en cas de handicap - #tous égaux, tous différents !\r\n\r\n\r\n🌳Vous voulez en savoir plus sur nos engagements ?\r\nNous nous mobilisons au quotidien autour de 4 piliers de responsabilité sociétale et environnementale majeurs : Offre responsable, Environnement, Solidarité, Humain.\r\nRendez-vous sur : https://www.auchan-agit.fr.\r\n', published_at='2024-04-30T14:15:15Z', remote='no', salary_currency='EUR', salary_maximum=23840, salary_minimum=19040, salary_period='yearly', salary_yearly_minimum=19040, sectors=[{'name': 'Grande distribution', 'reference': 'mass-distribution', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'E-commerce', 'reference': 'e-commerce-1', 'parent_name': 'Distribution', 'parent_reference': 'distribution-1'}, {'name': 'Grande consommation', 'reference': 'consumer-goods', 'parent_name': 'Food et boisson', 'parent_reference': 'food-and-beverage'}]),
# ...
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=None, contract_type='freelance', education_level=None, experience_level_minimum=None, has_contract_duration=False, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=False, language='fr', name="Apporteur d'affaires H/F", new_profession=Profession(category_name='Vente et service à la clientèle', sub_category_name='Vente', sub_category_reference='sales-jODFh'), offices=[Office(country='France', local_city='Marseille', local_state="Provence-Alpes-Côte d'Azur")], organization=Organization(description='Média-Start est une agence de presse et média qui vise à donner de la visibilité aux petites et moyennes entreprises en leur permettant d’accéder aux plus grands médias nationaux. À travers des contrats de partenariats noués avec les grands groupes médiatiques, Média-Start permet aux TPE et PME de gagner en visibilité et en notoriété en leur permettant de publier sur des supports de premier plan à forte visibilité.', name='Media-Start', nb_employees=20), profile="🐺 Ton animal fétiche est l'aigle, le loup, le requin ou le lion ?  \n🤑 Tu cherches une mission où tu seras rémunéré à la hauteur de ton travail ?  \n📈 Tu cherches une entreprise qui priorise la méritocratie ?  \n💰 Tu as besoin de voir les fruits de ton travail rapidement ?  \n🖊 Tu en as marre la paperasse qui incombe aux commerciaux ?  \n  \nChez Media-Start nous cherchons des chasseurs prêts à développer leur propre portefeuille de client BtoB en autonomie.  \nNos apporteurs d'affaires sont commissionnés sur le CA que génére. Ce variable est déplafonné et versé sur toutes les quinzaines !  \n  \nPour te permettre de réussir, nous te proposons :  \n  \n✅ Un accompagnement sur nos techniques de ventes : parce qu'on estime que tout le monde peut s'enrichir des bonnes pratiques de chacun.  \n  \n✅ Des outils optimisés qui te faciliteront le travail : fini la perte de temps à chercher qui contacter, notre CRM est optimisé, et tu auras accès à l'ensemble des outils qui te permettront de développer rapidement et efficacement ton portefeuille.  \n  \n✅ Un account management qui prend le relais du suivi de tes clients dès que tu as signé le devis : fini la gestion administrative, une fois signé, tu n'as plus qu'à te concentrer sur tes prochains clients !  \n  \n✅ Une ambiance de travail agréable, bienveillante et saine : car pour nous sommes convaincus que la réussite de nos collaborateurs passe aussi par leurs bien-être.", published_at='2024-04-25T14:44:31Z', remote='fulltime', salary_currency=None, salary_maximum=None, salary_minimum=None, salary_period=None, salary_yearly_minimum=None, sectors=[{'name': 'Média', 'reference': 'media-1', 'parent_name': 'Culture / Média / Divertissement', 'parent_reference': 'culture-media-entertainment'}, {'name': 'Presse écrite', 'reference': 'print-media', 'parent_name': 'Culture / Média / Divertissement', 'parent_reference': 'culture-media-entertainment'}, {'name': 'Publicité', 'reference': 'advertising', 'parent_name': 'Publicité / Marketing / Agence', 'parent_reference': 'advertising-marketing-agency'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=None, contract_type='full_time', education_level='bac_5', experience_level_minimum=5.0, has_contract_duration=False, has_education_level=True, has_experience_level_minimum=True, has_remote=True, has_salary_yearly_minimum=False, language='fr', name='Responsable supply chain', new_profession=Profession(category_name='Transport et logistique', sub_category_name="Logistique et gestion de la chaîne d'approvisionnement", sub_category_reference='logistics-and-supply-chain-management-0ODFi'), offices=[Office(country='France', local_city='Marseille', local_state="Provence-Alpes-Côte d'Azur")], organization=Organization(description='DualSun, fabricant français de panneaux solaires hybrides, qui fait partie de la French Tech Green20, est une entreprise qui se démarque par l’innovation et a su développer un savoir-faire français encore inégalé sur une technologie d’avenir. Son panneau solaire 2-en-1 produit à la fois de l’électricité et de l’eau chaude : au total, il permet d’obtenir 2,5 fois plus d’énergie qu’un panneau photovoltaïque standard tout en gardant les mêmes dimensions.\r\n\r\nCertifié made in France, il est conçu par l’équipe d’ingénieurs basée à Marseille et fabriqué dans une usine dédiée à Jujurieux (Région Auvergne Rhône Alpes).\r\n\r\nLa mission de DualSun : développer des systèmes solaires qui proposent à la fois électricité et chaleur pour tendre vers des bâtiments positifs en énergie. DualSun est une société industrielle en pleine croissance.', name='DualSun', nb_employees=65), profile="Issu(e) d’une formation Bac+4/5, idéalement ingénieur, vous avez au moins 5 ans d'expérience dans la supply chain.\n\nMéthodique et rigoureux, vous possédez un esprit d’analyse et de synthèse ainsi qu’une connaissance du terrain..\n\nVous êtes doté de fortes capacités relationnelles et avez eu l’occasion de prouver vos compétences managériales.\n\nVous avez une excellente maîtrise de l’anglais écrit et oral professionnel\xa0\n\nVous êtes force de proposition et familier des démarches d’amélioration continues\n\nVous êtes concerné(e) par les défis énergétiques qui se présentent au monde d’aujourd’hui, point essentiel pour une bonne intégration à notre équipe !\n\n### Compétences\n\nPriorité 1 : Capacité à animer une équipe, management, connaissance fine de la supply chain industrielle, esprit de synthèse\n\nPriorité 2 : A l’aise avec la data, capable de structurer et consolider les entrées de donnés pour piloter l’activité et prendre des décisions\n\nPriorité 3 : Capacité de négociation, à l'aise dans la relation avec les fournisseurs\n\nPriorité 4 : Rigueur, esprit critique et d’amélioration process, bonne capacité d’analyse et de compréhension de l’existant", published_at='2024-04-25T14:24:35Z', remote='punctual', salary_currency=None, salary_maximum=None, salary_minimum=None, salary_period=None, salary_yearly_minimum=None, sectors=[{'name': 'Environnement / Développement durable', 'reference': 'environment-sustainable-development', 'parent_name': 'Santé / Social / Environnement', 'parent_reference': 'health-social-environment'}, {'name': 'SaaS / Cloud Services', 'reference': 'saas-cloud-services', 'parent_name': 'Tech', 'parent_reference': 'tech-1'}, {'name': 'Energie', 'reference': 'energy', 'parent_name': 'Industrie', 'parent_reference': 'industry-1'}]),
#  JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=None, contract_type='full_time', education_level=None, experience_level_minimum=2.0, has_contract_duration=False, has_education_level=False, has_experience_level_minimum=True, has_remote=True, has_salary_yearly_minimum=False, language='fr', name='Consultant technique Salesforce (H/F)', new_profession=Profession(category_name='Technologie et ingénierie', sub_category_name='Assistance et services informatiques', sub_category_reference='it-support-and-services-3Njcy'), offices=[Office(country='France', local_city='Marseille', local_state="Provence-Alpes-Côte d'Azur")], organization=Organization(description='Klint est un cabinet de conseil et intégrateur spécialisé dans la Relation Client et la Data depuis 23 ans, reconnu pour son expertise\u202fen CRM, Marketing et BI.\nSa mission est de donner aux entreprises les meilleures solutions pour servir leurs enjeux business.\n\nKlint est partenaire des éditeurs de solutions leaders sur le marché : Salesforce, Microsoft, HubSpot et Oracle.\n\nLa confiance est une valeur importante, tant pour celle portée à ses 120 collaborateurs que pour la confiance que lui porte ses clients.', name='Klint Consulting', nb_employees=120), profile="Diplômé d’un BAC+5 école d’ingénieur ou équivalent universitaire, vous avez une expérience solide d’au moins 2 ans sur des projets Salesforce. Vous avez au moins les certifications Administrateur et Platform Developer I et vous avez un bon niveau d’anglais (écrit et oral).\n\nVous maîtrisez\xa0:\n\n* Administration de la plateforme Salesforce\n    \n* Flows\n    \n* Aura Components et/ou LWC\n    \n* Apex\n    \n* HTML, JS et CSS\n    \n\nDe nature curieuse, vous souhaitez vous investir dans des projets CRM autour des solutions Salesforce, suivre les évolutions du produit en faisant de la veille technologique et valider vos acquis en passant des certifications.\n\nVous avez des qualités relationnelles et d'écoute, êtes doué (e ) d’un réel sens du service client, aimez travailler et contribuer à la progression de l’équipe, partager des connaissances et apprendre au contact de nos partenaires et clients.\n\nSi vous souhaitez relever de nouveaux défis au sein d’une entreprise à taille humaine, être impliqué au sein d’une équipe en pleine croissance, tout ça dans une ambiance chaleureuse et ponctuée d’évènements festifs alors cliquez ici et rencontrons-nous vite\xa0!", published_at='2024-04-25T13:12:26Z', remote='partial', salary_currency=None, salary_maximum=None, salary_minimum=None, salary_period=None, salary_yearly_minimum=None, sectors=[{'name': 'Logiciels', 'reference': 'software-1', 'parent_name': 'Tech', 'parent_reference': 'tech-1'}, {'name': 'Digital Marketing / Data Marketing', 'reference': 'digital-marketing-data-marketing', 'parent_name': 'Conseil / Audit', 'parent_reference': 'consulting-audit'}, {'name': 'IT / Digital', 'reference': 'it-digital-1', 'parent_name': 'Conseil / Audit', 'parent_reference': 'consulting-audit'}]),
#  JobOffer(benefits=['Temps partiel possible', "Jusqu'à 1-2 jours de télétravail", 'Tickets restaurant', 'Restaurant d’entreprise / Cuisine pour les employés', 'Open space', "Politique d'égalité salariale", 'Recrutement encourageant la diversité', 'Manifeste sur la diversité', 'Formation sur les biais inconscients', 'Congé sabbatique', 'Congés payés', 'RTT', 'Intéressement & participation', 'Plan d’épargne entreprise (PEE)', 'Prime de cooptation', 'Team building', 'Afterworks', 'Partenariat avec des associations', 'Plan de développement', 'Financement des certifications', 'Formations sur le temps de travail', 'Séminaires & formations professionnelles', 'Formations en ligne', 'Formation en leadership', 'Prime de naissance', 'Congé de solidarité familiale', 'Congés pour enfant malade', 'Avantages liés à l’adoption', 'Congé paternité', 'Congé maternité', 'Solution de prévention santé mentale', 'Mutuelle santé', 'Maintien du salaire à 100% dès le premier jour d’arrêt maladie', 'Congés maladie', 'Prévoyance', 'Plan d’épargne pour la retraite collectif (PERCO)', 'Remboursement des transports publics'], contract_duration_maximum=12, contract_duration_minimum=12, contract_type='apprenticeship', education_level='bac_2', experience_level_minimum=0.0, has_contract_duration=True, has_education_level=True, has_experience_level_minimum=True, has_remote=True, has_salary_yearly_minimum=True, language='fr', name='Intervenant social -  ALTERNANCE - Adoma (13) H/F', new_profession=Profession(category_name='Enseignement', sub_category_name='Services de soutien scolaire', sub_category_reference='school-support-services-mNTFj'), offices=[Office(country='France', local_city='Marseille', local_state="Provence-Alpes-Côte d'Azur")], organization=Organization(description="CDC Habitat, filiale de la Caisse des Dépôts et opérateur de la Banque des territoires, est un groupe expert des métiers de la gestion locative, de la construction, de la rénovation et de la valorisation de l’habitat et de la ville. \r\n\r\nDans l’Hexagone et les Outre-mer, CDC Habitat est au service de l’habitat d’intérêt public à travers la gestion de plus de 554 000 logements, couvrant tous les besoins : solutions d’hébergement d’urgence, logements très sociaux et sociaux, logements intermédiaires et libres, résidences étudiantes et foyers de jeunes travailleurs, résidences pour seniors ou intergénérationnelles, établissements pour personnes âgées dépendantes, accession sociale à la propriété, libre et à prix maîtrisé.\r\n\r\nLes 10 800 collaborateurs du Groupe conçoivent et animent des lieux de vie adaptés aux évolutions sociétales et aux défis environnementaux et agissent concrètement pour l’intérêt général.\r\n\r\nComment ?\r\n\r\n- En apportant des solutions sur-mesure aux personnes âgées, aux étudiants, aux jeunes actifs et aux personnes en situation d’exclusion.\r\n\r\n- En participant au développement des territoires en construisant et louant des logements.\r\n\r\n- En combinant toutes les expertises en matière de développement et de maitrise d'ouvrage, de relation clients et de gestion des copropriétés.\r\n", name='CDC HABITAT', nb_employees=10800), profile="<p>Vous préparez un diplôme en travail social de <strong>niveau BAC +3 (CESF)</strong> et connaissez l'environnement des publics accueillis, le droit de l'asile et les partenaires institutionnels.<br />Doté(e) d'un bon relationnel, vous appréciez le travail en équipe.<br />Vous disposez de fortes capacités rédactionnelles et d'argumentation.<br />Vous savez faire preuve de réserve et de distanciation.<br /> Vous maîtrisez les outils informatiques (Pack Office).<br />Permis B.<br /><br /><br /></p>", published_at='2024-04-25T13:00:13Z', remote='no', salary_currency='EUR', salary_maximum=20000, salary_minimum=11000, salary_period='yearly', salary_yearly_minimum=11000, sectors=[{'name': 'Immobilier particulier', 'reference': 'residential-real-estate', 'parent_name': 'Immobilier', 'parent_reference': 'real-estate'}])]

# %%
markerting_embeddings = embed_offer_list(marketing_results, chunk_size=50)
ml_eng_embeddings = embed_offer_list(ml_eng_results, chunk_size=50)
po_embeddings = embed_offer_list(po_results, chunk_size=50)
boucher_embeddings = embed_offer_list(boucher_results, chunk_size=50)

# %%
from dataclasses import dataclass

@dataclass
class Offer():
    embedding: EmbeddingResponse
    offer: JobOffer


offers = []
for i, embedding in enumerate(ml_eng_embeddings):
    offers.append(Offer(embedding=embedding, offer=ml_eng_results[i]))
for i, embedding in enumerate(boucher_embeddings):
    offers.append(Offer(embedding=embedding, offer=boucher_results[i]))
for i, embedding in enumerate(markerting_embeddings):
    offers.append(Offer(embedding=embedding, offer=marketing_results[i]))
for i, embedding in enumerate(po_embeddings):
    offers.append(Offer(embedding=embedding, offer=po_results[i]))

# %%
def get_text_embedding(input):
    embeddings_batch_response = client.embeddings(model="mistral-embed", input=input)
    return embeddings_batch_response.data[0].embedding


def get_k_most_similar_offers(reference_embedding, offers, k=5):
    similar_offers = []
    for offer in offers:
        distance = euclidean_distances([offer.embedding.embedding], [reference_embedding])[0][0]
        similar_offers.append((offer, distance))

    # Sort the offers based on distance in ascending order
    similar_offers.sort(key=lambda x: x[1])

    # Return the top k most similar offers
    return similar_offers[:k]


reference_sentence = "I'm looking for an internship in London."
reference_embedding = get_text_embedding(reference_sentence)

# %%
k_most_similar_offers = get_k_most_similar_offers(reference_embedding, offers, k=10)
for offer, distance in k_most_similar_offers:
    print("Distance:", distance)
    print("Offer:", offer.offer.metadata_repr())
# Out:
# Distance: 0.7367216294390317
# Offer: This job offer named 'Marketing Intern - UK Market' was published on May 08, 2024. It is from the company 'Aircall'. It is located in London, United Kingdom. Sectors: SaaS / Cloud Services, Electronique / Télécommunications.
# Distance: 0.7501276634233847
# Offer: This job offer named 'B2B Business developer UK - Internship' was published on May 03, 2024. It is from the company 'Club Employés'. It is located in London, United Kingdom, Marseille, France, Lyon, France, Paris, France. Sectors: SaaS / Cloud Services, Art de vivre.
# Distance: 0.7535626826119545
# Offer: This job offer named 'Internship - Marketing Assistant M/F' was published on April 29, 2024. It is from the company 'Onepilot'. It is located in Paris, France. Sectors: Intelligence artificielle / Machine Learning, SaaS / Cloud Services, Accompagnement d'entreprises.
# Distance: 0.753813184401199
# Offer: This job offer named 'Marketing & Communication - Internship - Paris' was published on May 06, 2024. It is from the company 'Indeez'. It is located in Paris, France. Sectors: Banque, FinTech / InsurTech, SocialTech / GreenTech. Salary period: yearly. Salary currency: EUR.
# Distance: 0.7545957612925783
# Offer: This job offer named 'MARKETING INTERN' was published on April 22, 2024. It is from the company 'Luxurynsight'. It is located in Paris, France. Sectors: Big Data, Luxe. Salary period: yearly. Salary currency: EUR.
# Distance: 0.7582513676949922
# Offer: This job offer named 'Internship web marketing / social media (German speaker)' was published on May 06, 2024. It is from the company 'Daan Technologies'. It is located in Paris, France. Sectors: Electronique / Télécommunications, E-commerce.
# Distance: 0.7628898877549757
# Offer: This job offer named 'Digital Marketing Intern' was published on April 17, 2024. It is from the company 'Cuure'. It is located in Paris, France. Sectors: Pharmaceutique / Biotechnologique, E-commerce, FoodTech. Salary period: monthly. Salary currency: EUR. Salary range: 700-1200 monthly.
# Distance: 0.7657928710227765
# Offer: This job offer named 'Internship - Digital Marketing - Italian Speaker' was published on April 25, 2024. It is from the company 'Numberly'. It is located in Paris, France. Sectors: Logiciels, Digital Marketing / Data Marketing, Big Data.
# Distance: 0.7672974391731896
# Offer: This job offer named 'Stagiaire Marketing Digital (H/F) - Digital Marketing Intern (M/F)' was published on April 30, 2024. It is from the company 'KOKORO lingua'. It is located in Paris, France, Neuchâtel, Switzerland. Sectors: Application mobile, Association, EdTech. Salary period: yearly. Salary currency: EUR.
# Distance: 0.7700662543651619
# Offer: This job offer named 'Marketing Intern - UK Market' was published on May 08, 2024. It is from the company 'Aircall'. It is located in Paris, France. Sectors: SaaS / Cloud Services, Electronique / Télécommunications.

# %%
offers[1555].offer
# Out:
# JobOffer(benefits=[], contract_duration_maximum=None, contract_duration_minimum=None, contract_type='internship', education_level=None, experience_level_minimum=None, has_contract_duration=False, has_education_level=False, has_experience_level_minimum=False, has_remote=True, has_salary_yearly_minimum=False, language='fr', name='Rédacteur / Rédactrice Marketing - Stage - Barcelone', new_profession=Profession(category_name='Communication, marketing et publicité', sub_category_name='Planification et stratégie marketing', sub_category_reference='marketing-strategy-and-planning-wNWU0'), offices=[Office(country='Spain', local_city='Barcelona', local_state='Catalunya')], organization=Organization(description="Eux, c'est papernest.\r\n\r\nCertains évoqueront les challenges ambitieux, d’autres, l’inégalable esprit d’équipe ou encore l’ambiance de travail survoltée, voire les trois en même temps. Une chose est sûre : chez eux, on ne s’ennuie pas. \r\n\r\nCe qui les anime : imaginer leurs prochains défis, surmonter les obstacles un à un et dépasser leurs objectifs. Comment ? En faisant le choix du succès à long terme, plutôt que celui de la facilité à court terme; en valorisant l’effort de chacun et en offrant la possibilité à leurs collaborateurs et collaboratrices de se perfectionner et de se développer.\xa0\xa0", name='Papernest', nb_employees=900), profile=None, published_at='2024-04-24T16:05:25Z', remote='partial', salary_currency=None, salary_maximum=None, salary_minimum=None, salary_period=None, salary_yearly_minimum=None, sectors=[{'name': 'Application mobile', 'reference': 'mobile-apps', 'parent_name': 'Tech', 'parent_reference': 'tech-1'}, {'name': 'Immobilier commercial', 'reference': 'commercial-real-estate', 'parent_name': 'Immobilier', 'parent_reference': 'real-estate'}, {'name': 'Immobilier particulier', 'reference': 'residential-real-estate', 'parent_name': 'Immobilier', 'parent_reference': 'real-estate'}])

# %%
offers[0].offer.requirements_repr()
# Out:
# "The profile sought for this position is: '<ul><li>5 ans d&#39;expérience ou plus en analyse quantitative, de préférence dans le secteur du jeu vidéo</li><li>Baccalauréat ou diplôme supérieur en mathématiques, informatique décisionnelle, économie, génie ou un autre champ technique</li><li>Excellente compréhension des pratiques commerciales et de la monétisation</li><li>Excellentes compétences sur SQL\xa0: expérience poussée en recherche dans des listes de données volumineuses et complexes</li><li>Connaissance d&#39;un langage de script, que ce soit R ou Python, un atout</li><li>Capacité démontrée à travailler dans un environnement dynamique, à respecter des échéanciers fluctuants et à gérer les priorités sur plusieurs projets simultanés</li><li>Excellent sens de l&#39;organisation, de la communication et des relations</li><li>À l&#39;aise et confiant pour offrir des présentations et communiquer des analyses</li><li>Excellente maîtrise de l&#39;anglais, écrit et oral (obligatoire)</li><li>Passion pour les jeux vidéo</li></ul><p>***</p><ul><li>5+ years of experience performing quantitative analysis, preferably in the game industry</li><li>Bachelor&#39;s degree or higher in Math, Business Intelligence, Economics, Engineering or another technical field</li><li>Sophisticated understanding of business and monetization</li><li>Excellent SQL skills: extensive experience querying large, complex data sets</li><li>Knowledge of a scripting language, either R or Python, is an asset</li><li>Proven ability to work in a fast-paced environment, meet ever-changing deadlines and handle priorities for multiple projects at once</li><li>Excellent organizational, communication and interpersonal skills</li><li>Comfortable and confident giving presentations and communicating analyses</li><li>Strong English skills, written and spoken (this is a must)</li><li>Passion for video games</li></ul>'."

# %%
len(offers)
# Out:
# 3592

# %%
offer.
